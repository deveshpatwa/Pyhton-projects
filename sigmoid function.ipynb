# %%
# logistic sigmoid function
def sigmoid(x):
    e = 2.178
    y = 1/ (1+(e**-x))
    return round(y,2)

# %%
a = []
for i in list(range(-10,10)):
    a.append(sigmoid(i))

# %%
import matplotlib.pyplot as plt
plt.plot(a)
plt.show()
