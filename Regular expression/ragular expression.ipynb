# %%
import re

# %%
# importing the data

# %%
with open("data.txt", "r") as file:
    data = file.read()

# %%
data[:100]
# Out:
# 'Dave Martin\n615-555-7164\n173 Main St., Springfield RI 55924\ndavemartin@bogusemail.com\n\nCharles Harri'

# %%
# pass a r at the start of a string to use it as raw text

# %%
print("h\ttab")
# Out:
# h	tab

# %%
print(r"h\ttab")
# Out:
# h\ttab

# %%
text = "helloabc679**7"

# %%
# this is to search any pattern in a text
re.search("abc",text)
# Out:
# <re.Match object; span=(5, 8), match='abc'>

# %%
re.search("H",text)

# %%
re.findall(r"l",text)
# Out:
# ['l', 'l']

# %%
re.split("a",text)
# Out:
# ['hello', 'bc679**7']

# %% [markdown]
# ![image.png](attachment:a0aa0a48-2c06-483a-812a-9561dbe4f7ac.png)

# %%
# special char

# %% [markdown]
# ![image.png](attachment:ed3c7ea7-3195-4eac-92e6-e0f6052a5aca.png)

# %%
text
# Out:
# 'helloabc679**7'

# %%
re.search(r"l.a",text)
# Out:
# <re.Match object; span=(3, 6), match='loa'>

# %%
re.search(r"^a",text)

# %%
re.search(r"\d",text)
# Out:
# <re.Match object; span=(8, 9), match='6'>

# %%
re.findall(r"\d",text)
# Out:
# ['6', '7', '9', '7']

# %%
find(r"\d")
# Out:
# []

# %%
re.findall(r"\D",text)
# Out:
# ['h', 'e', 'l', 'l', 'o', 'a', 'b', 'c', '*', '*']

# %%
re.findall(r"\D",text)
# Out:
# ['h', 'e', 'l', 'l', 'o', 'a', 'b', 'c', '*', '*']

# %%
a = open("data.txt",'a')

# %%
re.findall("^[h]",text)
# Out:
# ['h']

# %%
text
# Out:
# 'helloabc679**7'

# %%
re.split("[a*6]",text)
# Out:
# ['hello', 'bc', '79', '', '7']

# %%
text = """
Mr. rohan
Mr kartik
Mrs. ritika
Mr. T
"""
re.findall(r"Mr[\.?]\s[A-Za-z]",text)
# Out:
# ['Mr. r', 'Mr. T']

# %%
import sys
sys.path.append("C:\\Users\\deves\\Documents\\GitHub\\Pyton")

# %%
import devesh

# %%
sys.path
# Out:
# ['C:\\Users\\deves\\miniconda3\\python312.zip',
#  'C:\\Users\\deves\\miniconda3\\DLLs',
#  'C:\\Users\\deves\\miniconda3\\Lib',
#  'C:\\Users\\deves\\miniconda3',
#  '',
#  'C:\\Users\\deves\\miniconda3\\Lib\\site-packages',
#  'C:\\Users\\deves\\miniconda3\\Lib\\site-packages\\win32',
#  'C:\\Users\\deves\\miniconda3\\Lib\\site-packages\\win32\\lib',
#  'C:\\Users\\deves\\miniconda3\\Lib\\site-packages\\Pythonwin',
#  'C:\\Users\\deves\\Documents\\GitHub\\Pyton']
