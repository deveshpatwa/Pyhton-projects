# %%
import pandas as pd
import bar_chart_race as race

# %% [raw]
# pip install bar_chart_race

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is C6E1-F1B2
#
#  Directory of C:\Users\deves\Documents\GitHub\Pyton\chart animation project
#
# 20-02-2026  05.49 PM    <DIR>          .
# 20-02-2026  05.33 PM    <DIR>          ..
# 20-02-2026  05.33 PM    <DIR>          .ipynb_checkpoints
# 20-02-2026  05.49 PM            18,118 code file.ipynb
# 20-02-2026  05.33 PM            63,622 issues.csv
# 20-02-2026  05.38 PM             9,468 Most Popular Programming Languages.csv
# 20-02-2026  05.33 PM            65,408 prs.csv
# 20-02-2026  05.33 PM             5,207 repos.csv
#                5 File(s)        161,823 bytes
#                3 Dir(s)  93,046,861,824 bytes free

# %%
df = pd.read_csv("Most Popular Programming Languages.csv")

# %%
df.columns = [i.split()[0] for i in  df.columns]

# %%
df.head()
# Out:
#      Month  Python  JavaScript  Java  C#  PhP  Flutter  React  Swift  \
# 0  2004-01      30          98    96  76  100        6      1      9
# 1  2004-02      29          98    97  86   99        6      2      9
# 2  2004-03      28         100   100  87   97        5      2      9
# 3  2004-04      28          98    97  89  100        6      1      9
# 4  2004-05      28          91    99  84   92        6      2     10
#
#    TypeScript  Matlab
# 0           2      78
# 1           1      91
# 2           2      99
# 3           2      95
# 4           3      86

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       249 non-null    object
#  1   Python      249 non-null    int64
#  2   JavaScript  249 non-null    int64
#  3   Java        249 non-null    int64
#  4   C#          249 non-null    int64
#  5   PhP         249 non-null    int64
#  6   Flutter     249 non-null    int64
#  7   React       249 non-null    int64
#  8   Swift       249 non-null    int64
#  9   TypeScript  249 non-null    int64
#  10  Matlab      249 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 21.5+ KB

# %%
df = df.set_index("Month")

# %% [markdown]
# bcr.bar_chart_race(
#     df=df,
#     filename='programming_languages.mp4',
#     orientation='h',
#     sort='desc',
#     n_bars=10,
#     fixed_order=False,
#     fixed_max=True,
#     steps_per_period=20,
#     period_length=500,
#     title='Popularity of Programming Languages Over Time'
# )

# %%
race.bar_chart_race(df=df,n_bars=10,fixed_max=True)
# Out:
# C:\Users\deves\miniconda3\Lib\site-packages\bar_chart_race\_make_chart.py:889: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_values.iloc[:, 0] = df_values.iloc[:, 0].fillna(method='ffill')
# C:\Users\deves\miniconda3\Lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(self.df_values.columns)
# C:\Users\deves\miniconda3\Lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ...

# %% [raw]
# pip install ffmpeg

# %%
race.bar_chart_race(
    df=df,
    filename='programming_languages.mp4',
    orientation='h',
    sort='desc',
    n_bars=10,
    fixed_order=False,
    fixed_max=True,
    steps_per_period=20,
    period_length=500,
    title='Popularity of Programming Languages Over Time')
# Out:
# C:\Users\deves\miniconda3\Lib\site-packages\bar_chart_race\_make_chart.py:889: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_values.iloc[:, 0] = df_values.iloc[:, 0].fillna(method='ffill')
# C:\Users\deves\miniconda3\Lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(self.df_values.columns)
# C:\Users\deves\miniconda3\Lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# MovieWriter ffmpeg unavailable; using Pillow instead.
# ---------------------------------------------------------------------------
# ...
