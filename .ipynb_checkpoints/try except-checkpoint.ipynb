# %%
try:
    print(a)
except:
    print("There was an error")
# Out:
# There was an error

# %%
a = 56

# %%
del a

# %%
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(b)
#
# NameError: name 'b' is not defined

# %%
d=  {1:100,2:200}
try:
    e[3]
except KeyError:
    print("there is no key")
except:
    print("something is wrong")
# Out:
# something is wrong

# %%
a=  "33.6"
try:
    a = int(a)
except ValueError:
    try:
        a = float(a)
    except:
        print("a is not a float or a int so its str")
        a = str(a)
    
        

print(a,type(a))
# Out:
# 33.6 <class 'float'>
