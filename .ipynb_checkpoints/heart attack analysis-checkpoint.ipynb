# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df['age'].plot(kind='hist',title='Age distribution of heart attack',xlabel='Age',ylabel='Frequency')
# Out:
# <Axes: title={'center': 'Age distribution of heart attack'}, xlabel='Age', ylabel='Frequency'>

# %%
df['cp'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trtbps       49
# chol        152
# fbs           2
# restecg       3
# thalachh     91
# exng          2
# oldpeak      40
# slp           3
# caa           5
# thall         4
# output        2
# dtype: int64

# %%
df['trtbps'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.heatmap(data=df)
# Out:
# <Axes: >

# %%
df['fbs'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['fbs'].nunique()
# Out:
# 2

# %%
mapper = {'fbs':'blood_sugger'}
df.rename(mapper,inplace=True,axis=1)

# %%
df['blood_sugger']=df['blood_sugger'].astype(str)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'blood_sugger', 'restecg',
#        'thalachh', 'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           303 non-null    int64
#  1   sex           303 non-null    int64
#  2   cp            303 non-null    int64
#  3   trtbps        303 non-null    int64
#  4   chol          303 non-null    int64
#  5   blood_sugger  303 non-null    object
#  6   restecg       303 non-null    int64
#  7   thalachh      303 non-null    int64
#  8   exng          303 non-null    int64
#  9   oldpeak       303 non-null    float64
#  10  slp           303 non-null    int64
#  11  caa           303 non-null    int64
#  12  thall         303 non-null    int64
#  13  output        303 non-null    int64
# dtypes: float64(1), int64(12), object(1)
# memory usage: 33.3+ KB

# %%
df['blood_sugger'].unique()
# Out:
# array(['1', '0'], dtype=object)

# %%
df.loc[df['blood_sugger']=='1','blood_sugger'] = 'Yes'

# %%
df.loc[df['blood_sugger']=='0','blood_sugger'] = 'No'

# %%
df.sample(10)
# Out:
#      age  sex  cp  trtbps  chol blood_sugger  restecg  thalachh  exng  \
# 44    39    1   2     140   321           No        0       182     0
# 138   57    1   0     110   201           No        1       126     1
# 276   58    1   0     146   218           No        1       105     0
# 113   43    1   0     110   211           No        1       161     0
# 40    51    0   2     140   308           No        0       142     0
# 196   46    1   2     150   231           No        1       147     0
# 0     63    1   3     145   233          Yes        0       150     0
# 81    45    1   1     128   308           No        0       170     0
# 66    51    1   2     100   222           No        1       143     1
# 26    59    1   2     150   212          Yes        1       157     0
#
#      oldpeak  slp  caa  thall  output
# 44       0.0    2    0      2       1
# 138      1.5    1    0      1       1
# 276      2.0    1    1      3       0
# 113      0.0    2    0      3       1
# ...

# %%
np.corrcoef(df,rowvar=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 np.corrcoef(df,rowvar=False)
#
# File <__array_function__ internals>:200, in corrcoef(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2846, in corrcoef(x, y, rowvar, bias, ddof, dtype)
#    2842 if bias is not np._NoValue or ddof is not np._NoValue:
#    2843     # 2015-03-15, 1.10
#    2844     warnings.warn('bias and ddof have no effect and are deprecated',
#    2845                   DeprecationWarning, stacklevel=3)
# -> 2846 c = cov(x, y, rowvar, dtype=dtype)
#    2847 try:
#    2848     d = diag(c)
#
# File <__array_function__ internals>:200, in cov(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2681, in cov(m, y, rowvar, bias, ddof, fweights, aweights, dtype)
#    2678     else:
#    2679         w *= aweights
# ...

# %%
df.nunique()

# %%
df['chol'].plot(kind='hist')

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol blood_sugger  restecg  thalachh  exng  oldpeak  \
# 0   63    1   3     145   233          Yes        0       150     0      2.3
# 1   37    1   2     130   250           No        1       187     0      3.5
# 2   41    0   1     130   204           No        0       172     0      1.4
# 3   56    1   1     120   236           No        1       178     0      0.8
# 4   57    0   0     120   354           No        1       163     1      0.6
#
#    slp  caa  thall  output
# 0    0    0      1       1
# 1    0    0      2       1
# 2    2    0      2       1
# 3    2    0      2       1
# 4    2    0      2       1

# %%
df['thalachh'].plot(style='-0')
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           303 non-null    int64
#  1   sex           303 non-null    int64
#  2   cp            303 non-null    int64
#  3   trtbps        303 non-null    int64
#  4   chol          303 non-null    int64
#  5   blood_sugger  303 non-null    object
#  6   restecg       303 non-null    int64
#  7   thalachh      303 non-null    int64
#  8   exng          303 non-null    int64
#  9   oldpeak       303 non-null    float64
#  10  slp           303 non-null    int64
#  11  caa           303 non-null    int64
#  12  thall         303 non-null    int64
#  13  output        303 non-null    int64
# dtypes: float64(1), int64(12), object(1)
# memory usage: 33.3+ KB

# %%
df['blood_sugger'].str.get(0)
# Out:
# 0      Y
# 1      N
# 2      N
# 3      N
# 4      N
#       ..
# 298    N
# 299    N
# 300    Y
# 301    N
# 302    N
# Name: blood_sugger, Length: 303, dtype: object

# %%
df['nblood_sugger'] = df['blood_sugger'].replace({'Yes':'yy','No':'nn'})

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol blood_sugger  restecg  thalachh  exng  oldpeak  \
# 0   63    1   3     145   233          Yes        0       150     0      2.3
# 1   37    1   2     130   250           No        1       187     0      3.5
# 2   41    0   1     130   204           No        0       172     0      1.4
# 3   56    1   1     120   236           No        1       178     0      0.8
# 4   57    0   0     120   354           No        1       163     1      0.6
#
#    slp  caa  thall  output nblood_sugger
# 0    0    0      1       1            yy
# 1    0    0      2       1            nn
# 2    2    0      2       1            nn
# 3    2    0      2       1            nn
# 4    2    0      2       1            nn

# %%
df['new_blood_sugger'] = df['blood_sugger'].map({'Yes':'yy','No':'nn'})

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol blood_sugger  restecg  thalachh  exng  oldpeak  \
# 0   63    1   3     145   233          Yes        0       150     0      2.3
# 1   37    1   2     130   250           No        1       187     0      3.5
# 2   41    0   1     130   204           No        0       172     0      1.4
# 3   56    1   1     120   236           No        1       178     0      0.8
# 4   57    0   0     120   354           No        1       163     1      0.6
#
#    slp  caa  thall  output nblood_sugger new_blood_sugger
# 0    0    0      1       1            yy               yy
# 1    0    0      2       1            nn               nn
# 2    2    0      2       1            nn               nn
# 3    2    0      2       1            nn               nn
# 4    2    0      2       1            nn               nn

# %%
df1=df.copy()

# %%
df1=df1['blood_sugger'].drop_duplicates()

# %%
type(df1)
# Out:
# pandas.core.series.Series

# %%
df1 = df.copy()

# %%
df1.duplicates()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14224\3657966773.py in ?()
# ----> 1 df1.duplicates()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'duplicates'

# %%
df1.shape
# Out:
# (302, 16)

# %%
df.shape
# Out:
# (303, 16)

# %%
df1['blood_sugger'].isin(['No'])
# Out:
# 258

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol blood_sugger  restecg  thalachh  exng  oldpeak  \
# 0   63    1   3     145   233          Yes        0       150     0      2.3
# 1   37    1   2     130   250           No        1       187     0      3.5
# 2   41    0   1     130   204           No        0       172     0      1.4
# 3   56    1   1     120   236           No        1       178     0      0.8
# 4   57    0   0     120   354           No        1       163     1      0.6
#
#    slp  caa  thall  output nblood_sugger new_blood_sugger
# 0    0    0      1       1            yy               yy
# 1    0    0      2       1            nn               nn
# 2    2    0      2       1            nn               nn
# 3    2    0      2       1            nn               nn
# 4    2    0      2       1            nn               nn

# %%
df.eval('col1 + col2')
# Out:
# 0      4
# 1      3
# 2      1
# 3      2
# 4      0
#       ..
# 298    0
# 299    4
# 300    1
# 301    1
# 302    1
# Length: 303, dtype: int64

# %%
url = (
    "https://raw.githubusercontent.com/pandas-dev"
    "/pandas/main/pandas/tests/io/data/csv/tips.csv"
)
newdf = pd.read_csv(url)

# %%
newdf
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import pandas as pd
# Out:
# 244

# %%
df
# Out:
#      age  sex  cp  trtbps  chol blood_sugger  restecg  thalachh  exng  \
# 0     63    1   3     145   233          Yes        0       150     0
# 1     37    1   2     130   250           No        1       187     0
# 2     41    0   1     130   204           No        0       172     0
# 3     56    1   1     120   236           No        1       178     0
# 4     57    0   0     120   354           No        1       163     1
# ..   ...  ...  ..     ...   ...          ...      ...       ...   ...
# 298   57    0   0     140   241           No        1       123     1
# 299   45    1   3     110   264           No        1       132     0
# 300   68    1   0     144   193          Yes        1       141     0
# 301   57    1   0     130   131           No        1       115     1
# 302   57    0   1     130   236           No        0       174     0
#
#      oldpeak  slp  caa  thall  output nblood_sugger new_blood_sugger
# ...

# %%
df.set_index('age')
# Out:
#      sex  cp  trtbps  chol blood_sugger  restecg  thalachh  exng  oldpeak  \
# age
# 63     1   3     145   233          Yes        0       150     0      2.3
# 37     1   2     130   250           No        1       187     0      3.5
# 41     0   1     130   204           No        0       172     0      1.4
# 56     1   1     120   236           No        1       178     0      0.8
# 57     0   0     120   354           No        1       163     1      0.6
# ..   ...  ..     ...   ...          ...      ...       ...   ...      ...
# 57     0   0     140   241           No        1       123     1      0.2
# 45     1   3     110   264           No        1       132     0      1.2
# 68     1   0     144   193          Yes        1       141     0      3.4
# 57     1   0     130   131           No        1       115     1      1.2
# 57     0   1     130   236           No        0       174     0      0.0
#
#      slp  caa  thall  output nblood_sugger new_blood_sugger
# age
# ...

# %%
df.query('age==41')
# Out:
#      age  sex  cp  trtbps  chol blood_sugger  restecg  thalachh  exng  \
# 2     41    0   1     130   204           No        0       172     0
# 30    41    0   1     105   198           No        1       168     0
# 63    41    1   1     135   203           No        1       132     0
# 80    41    1   2     112   250           No        1       179     0
# 116   41    1   2     130   214           No        0       168     0
# 122   41    0   2     112   268           No        0       172     1
# 133   41    1   1     110   235           No        1       153     0
# 134   41    0   1     126   306           No        1       163     0
# 162   41    1   1     120   157           No        1       182     0
# 189   41    1   0     110   172           No        0       158     0
#
#      oldpeak  slp  caa  thall  output nblood_sugger new_blood_sugger
# 2        1.4    2    0      2       1            nn               nn
# ...

# %%
df.loc[(df.age==41) & (df.restecg==1)]
# Out:
#      age  sex  cp  trtbps  chol blood_sugger  restecg  thalachh  exng  \
# 30    41    0   1     105   198           No        1       168     0
# 63    41    1   1     135   203           No        1       132     0
# 80    41    1   2     112   250           No        1       179     0
# 133   41    1   1     110   235           No        1       153     0
# 134   41    0   1     126   306           No        1       163     0
# 162   41    1   1     120   157           No        1       182     0
#
#      oldpeak  slp  caa  thall  output nblood_sugger new_blood_sugger
# 30       0.0    2    1      2       1            nn               nn
# 63       0.0    1    0      1       1            nn               nn
# 80       0.0    2    0      2       1            nn               nn
# 133      0.0    2    0      2       1            nn               nn
# 134      0.0    2    0      2       1            nn               nn
# ...

# %%
df.age.mean()
# Out:
# 54.366336633663366

# %%
df.age.unique()
# Out:
# array([63, 37, 41, 56, 57, 44, 52, 54, 48, 49, 64, 58, 50, 66, 43, 69, 59,
#        42, 61, 40, 71, 51, 65, 53, 46, 45, 39, 47, 62, 34, 35, 29, 55, 60,
#        67, 68, 74, 76, 70, 38, 77], dtype=int64)

# %%
df.age.value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol blood_sugger  restecg  thalachh  exng  oldpeak  \
# 0   63    1   3     145   233          Yes        0       150     0      2.3
# 1   37    1   2     130   250           No        1       187     0      3.5
# 2   41    0   1     130   204           No        0       172     0      1.4
# 3   56    1   1     120   236           No        1       178     0      0.8
# 4   57    0   0     120   354           No        1       163     1      0.6
#
#    slp  caa  thall  output nblood_sugger new_blood_sugger
# 0    0    0      1       1            yy               yy
# 1    0    0      2       1            nn               nn
# 2    2    0      2       1            nn               nn
# 3    2    0      2       1            nn               nn
# 4    2    0      2       1            nn               nn

# %%
meanage = df.age.mean()

# %%
df['new_age'] = df.age - meanage
df.head()
# Out:
#    age  sex  cp  trtbps  chol blood_sugger  restecg  thalachh  exng  oldpeak  \
# 0   63    1   3     145   233          Yes        0       150     0      2.3
# 1   37    1   2     130   250           No        1       187     0      3.5
# 2   41    0   1     130   204           No        0       172     0      1.4
# 3   56    1   1     120   236           No        1       178     0      0.8
# 4   57    0   0     120   354           No        1       163     1      0.6
#
#    slp  caa  thall  output nblood_sugger new_blood_sugger    new_age
# 0    0    0      1       1            yy               yy   8.633663
# 1    0    0      2       1            nn               nn -17.366337
# 2    2    0      2       1            nn               nn -13.366337
# 3    2    0      2       1            nn               nn   1.633663
# 4    2    0      2       1            nn               nn   2.633663

# %%
df['sna'] = df.new_age*df.new_age

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol blood_sugger  restecg  thalachh  exng  oldpeak  \
# 0   63    1   3     145   233          Yes        0       150     0      2.3
# 1   37    1   2     130   250           No        1       187     0      3.5
# 2   41    0   1     130   204           No        0       172     0      1.4
# 3   56    1   1     120   236           No        1       178     0      0.8
# 4   57    0   0     120   354           No        1       163     1      0.6
#
#    slp  caa  thall  output nblood_sugger new_blood_sugger    new_age  \
# 0    0    0      1       1            yy               yy   8.633663
# 1    0    0      2       1            nn               nn -17.366337
# 2    2    0      2       1            nn               nn -13.366337
# 3    2    0      2       1            nn               nn   1.633663
# 4    2    0      2       1            nn               nn   2.633663
#
#           sna
# 0   74.540143
# 1  301.589648
# 2  178.658955
# 3    2.668856
# ...

# %%
import math
math.sqrt(df.sna.mean())
# Out:
# 9.067101638577872

# %%
meanage
# Out:
# 54.366336633663366

# %%
df.output.value_counts()
# Out:
# output
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
df.query('output==1').blood_sugger.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
import seaborn as sns

# %%
sns.lineplot(data=df.chol, label = 'chaloryyyy')
# Out:
# <Axes: ylabel='chol'>

# %%
df.chol.plot()
# Out:
# <Axes: >

# %%
newdf
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
list(df.columns)
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trtbps',
#  'chol',
#  'blood_sugger',
#  'restecg',
#  'thalachh',
#  'exng',
#  'oldpeak',
#  'slp',
#  'caa',
#  'thall',
#  'output',
#  'nblood_sugger',
#  'new_blood_sugger',
#  'new_age',
#  'sna']

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol blood_sugger  restecg  thalachh  exng  oldpeak  \
# 0   63    1   3     145   233          Yes        0       150     0      2.3
# 1   37    1   2     130   250           No        1       187     0      3.5
# 2   41    0   1     130   204           No        0       172     0      1.4
# 3   56    1   1     120   236           No        1       178     0      0.8
# 4   57    0   0     120   354           No        1       163     1      0.6
#
#    slp  caa  thall  output nblood_sugger new_blood_sugger    new_age  \
# 0    0    0      1       1            yy               yy   8.633663
# 1    0    0      2       1            nn               nn -17.366337
# 2    2    0      2       1            nn               nn -13.366337
# 3    2    0      2       1            nn               nn   1.633663
# 4    2    0      2       1            nn               nn   2.633663
#
#           sna
# 0   74.540143
# 1  301.589648
# 2  178.658955
# 3    2.668856
# ...

# %%
def pp(a):
    if a.sex ==1:
        return "hello"
    else:
        return 'goodby'

# %%
df['hello_goodby'] = df.apply(pp,axis='columns')

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol blood_sugger  restecg  thalachh  exng  oldpeak  \
# 0   63    1   3     145   233          Yes        0       150     0      2.3
# 1   37    1   2     130   250           No        1       187     0      3.5
# 2   41    0   1     130   204           No        0       172     0      1.4
# 3   56    1   1     120   236           No        1       178     0      0.8
# 4   57    0   0     120   354           No        1       163     1      0.6
#
#    slp  caa  thall  output nblood_sugger new_blood_sugger    new_age  \
# 0    0    0      1       1            yy               yy   8.633663
# 1    0    0      2       1            nn               nn -17.366337
# 2    2    0      2       1            nn               nn -13.366337
# 3    2    0      2       1            nn               nn   1.633663
# 4    2    0      2       1            nn               nn   2.633663
#
#           sna hello_goodby
# 0   74.540143        hello
# 1  301.589648        hello
# ...

# %%
df.sex.value_counts()
# Out:
# sex
# 1    207
# 0     96
# Name: count, dtype: int64

# %%
df.groupby('sex').sex.count()
# Out:
# sex
# 0     96
# 1    207
# Name: sex, dtype: int64

# %%
df.groupby('sex').thalachh.mean()
# Out:
# sex
# 0    151.125000
# 1    148.961353
# Name: thalachh, dtype: float64

# %%
df.sex = df.sex.map({np.nan:'male',0:'female'})

# %%
df.head()
# Out:
#    age   sex  cp  trtbps  chol blood_sugger  restecg  thalachh  exng  oldpeak  \
# 0   63  male   3     145   233          Yes        0       150     0      2.3
# 1   37  male   2     130   250           No        1       187     0      3.5
# 2   41  male   1     130   204           No        0       172     0      1.4
# 3   56  male   1     120   236           No        1       178     0      0.8
# 4   57  male   0     120   354           No        1       163     1      0.6
#
#    slp  caa  thall  output nblood_sugger new_blood_sugger    new_age  \
# 0    0    0      1       1            yy               yy   8.633663
# 1    0    0      2       1            nn               nn -17.366337
# 2    2    0      2       1            nn               nn -13.366337
# 3    2    0      2       1            nn               nn   1.633663
# 4    2    0      2       1            nn               nn   2.633663
#
#           sna hello_goodby
# 0   74.540143        hello
# ...

# %%
df.groupby(['sex','blood_sugger']).thalachh.agg([min,max,sum,len]).plot(kind='bar')
# Out:
# <Axes: xlabel='sex,blood_sugger'>

# %%
df.thalachh.mean()
# Out:
# 149.64686468646866

# %%
df.blood_sugger.dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# age                   int64
# sex                  object
# cp                    int64
# trtbps                int64
# chol                  int64
# blood_sugger         object
# restecg               int64
# thalachh              int64
# exng                  int64
# oldpeak             float64
# slp                   int64
# caa                   int64
# thall                 int64
# output                int64
# nblood_sugger        object
# new_blood_sugger     object
# new_age             float64
# sna                 float64
# hello_goodby         object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               303 non-null    int64
#  1   sex               303 non-null    object
#  2   cp                303 non-null    int64
#  3   trtbps            303 non-null    int64
#  4   chol              303 non-null    int64
#  5   blood_sugger      303 non-null    object
#  6   restecg           303 non-null    int64
#  7   thalachh          303 non-null    int64
#  8   exng              303 non-null    int64
#  9   oldpeak           303 non-null    float64
#  10  slp               303 non-null    int64
#  11  caa               303 non-null    int64
#  12  thall             303 non-null    int64
#  13  output            303 non-null    int64
#  14  nblood_sugger     303 non-null    object
#  15  new_blood_sugger  303 non-null    object
# ...

# %%
df1.age=df1.age.astype(np.int8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[218], line 1
# ----> 1 df1.age=df1.age.astype(np.int8)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# --> 451 return self.apply(
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               303 non-null    object
#  1   sex               303 non-null    int64
#  2   cp                303 non-null    int64
#  3   trtbps            303 non-null    int64
#  4   chol              303 non-null    int64
#  5   blood_sugger      303 non-null    object
#  6   restecg           303 non-null    int64
#  7   thalachh          303 non-null    int64
#  8   exng              303 non-null    int64
#  9   oldpeak           303 non-null    float64
#  10  slp               303 non-null    int64
#  11  caa               303 non-null    int64
#  12  thall             303 non-null    int64
#  13  output            303 non-null    int64
#  14  nblood_sugger     303 non-null    object
#  15  new_blood_sugger  303 non-null    object
# ...

# %%
df1.head()
# Out:
#     age  sex  cp  trtbps  chol blood_sugger  restecg  thalachh  exng  oldpeak  \
# 0  63.0    1   3     145   233          Yes        0       150     0      2.3
# 1  37.0    1   2     130   250           No        1       187     0      3.5
# 2  41.0    0   1     130   204           No        0       172     0      1.4
# 3  56.0    1   1     120   236           No        1       178     0      0.8
# 4  57.0    0   0     120   354           No        1       163     1      0.6
#
#    slp  caa  thall  output nblood_sugger new_blood_sugger
# 0    0    0      1       1            yy               yy
# 1    0    0      2       1            nn               nn
# 2    2    0      2       1            nn               nn
# 3    2    0      2       1            nn               nn
# 4    2    0      2       1            nn               nn

# %%
df.head()
# Out:
#     age   sex  cp  trtbps  chol blood_sugger  restecg  thalachh  exng  \
# 0  63.0  male   3     145   233          Yes        0       150     0
# 1  37.0  male   2     130   250           No        1       187     0
# 2  41.0  male   1     130   204           No        0       172     0
# 3  56.0  male   1     120   236           No        1       178     0
# 4  57.0  male   0     120   354           No        1       163     1
#
#    oldpeak  slp  caa  thall  output nblood_sugger new_blood_sugger    new_age  \
# 0      2.3    0    0      1       1            yy               yy   8.633663
# 1      3.5    0    0      2       1            nn               nn -17.366337
# 2      1.4    2    0      2       1            nn               nn -13.366337
# 3      0.8    2    0      2       1            nn               nn   1.633663
# 4      0.6    2    0      2       1            nn               nn   2.633663
#
#           sna hello_goodby
# 0   74.540143        hello
# ...

# %%
df.output.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 298    False
# 299    False
# 300    False
# 301    False
# 302    False
# Name: output, Length: 303, dtype: bool

# %%
df.sex.notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 298    True
# 299    True
# 300    True
# 301    True
# 302    True
# Name: sex, Length: 303, dtype: bool

# %%
df.sex.iloc[5:15] = np.nan
# Out:
# C:\Users\deves\AppData\Local\Temp\ipykernel_14224\1813669678.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sex.iloc[5:15] = np.nan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               303 non-null    object
#  1   sex               293 non-null    object
#  2   cp                303 non-null    int64
#  3   trtbps            303 non-null    int64
#  4   chol              303 non-null    int64
#  5   blood_sugger      303 non-null    object
#  6   restecg           303 non-null    int64
#  7   thalachh          303 non-null    int64
#  8   exng              303 non-null    int64
#  9   oldpeak           303 non-null    float64
#  10  slp               303 non-null    int64
#  11  caa               303 non-null    int64
#  12  thall             303 non-null    int64
#  13  output            303 non-null    int64
#  14  nblood_sugger     303 non-null    object
#  15  new_blood_sugger  303 non-null    object
# ...

# %%
df.sex.isnull().sum()
# Out:
# 10

# %%
df.sex=df.sex.fillna('hello')

# %%
df.sex.unique()
# Out:
# array(['male', 'hello'], dtype=object)

# %%
df.sex.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>
