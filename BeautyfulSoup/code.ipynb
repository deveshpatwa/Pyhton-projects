# %%
from bs4 import BeautifulSoup as bs

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is C6E1-F1B2
#
#  Directory of C:\Users\deves\Documents\GitHub\Pyton\BeautyfulSoup
#
# 24-01-2026  11.42 AM    <DIR>          .
# 24-01-2026  11.39 AM    <DIR>          ..
# 24-01-2026  11.40 AM    <DIR>          .ipynb_checkpoints
# 24-01-2026  11.39 AM           100,902 Simple Website.html
# 24-01-2026  11.39 AM    <DIR>          Simple Website_files
# 24-01-2026  11.42 AM               837 Untitled.ipynb
#                2 File(s)        101,739 bytes
#                4 Dir(s)  105,667,059,712 bytes free

# %%
with open("Simple Website.html",) as html_file:
    soup = bs(html_file)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[5], line 2
#       1 with open("Simple Website.html") as html_file:
# ----> 2     soup = bs(html_file)
#
# File ~\miniconda3\Lib\site-packages\bs4\__init__.py:314, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     311 self.parse_only = parse_only
#     313 if hasattr(markup, 'read'):        # It's a file-type object.
# --> 314     markup = markup.read()
#     315 elif len(markup) <= 256 and (
#     316         (isinstance(markup, bytes) and not b'<' in markup)
#     317         or (isinstance(markup, str) and not '<' in markup)
#    (...)
#     321     # Beautiful Soup will still parse the input as markup,
#     322     # since that is sometimes the intended behavior.
#     323     if not self._markup_is_url(markup):
#
# ...

# %%
import requests as r

# %%
url = "https://httpbin.org/get"

# %%
data = r.get(url)

# %%
data.status_code
# Out:
# 200

# %%
data.text
# Out:
# '{\n  "args": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br, zstd", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.32.3", \n    "X-Amzn-Trace-Id": "Root=1-69746666-0c0349b327cf7f4222b01737"\n  }, \n  "origin": "223.177.36.214", \n  "url": "https://httpbin.org/get"\n}\n'
