# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# new code added

df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
print(df)
# Out:
#    col1  col2
# 0     1     3
# 1     2     4
