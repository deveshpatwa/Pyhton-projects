# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('people.csv',index_col='Index')

# %%
df.head()
# Out:
#                User Id First Name Last Name     Sex  \
# Index
# 1      8717bbf45cCDbEe     Shelia   Mahoney    Male
# 2      3d5AD30A4cD38ed         Jo    Rivers  Female
# 3      810Ce0F276Badec     Sheryl    Lowery  Female
# 4      BF2a889C00f0cE1    Whitney    Hooper    Male
# 5      9afFEafAe1CBBB9    Lindsey      Rice  Female
#
#                                Email               Phone Date of birth  \
# Index
# 1                pwarner@example.org        857.139.8239    2014-01-27
# 2      fergusonkatherine@example.net     +1-950-759-8687    1931-07-26
# 3                fhoward@example.org       (599)782-0605    2013-11-25
# 4              zjohnston@example.com     +1-939-130-6258    2012-11-17
# 5                   elin@example.net  (390)417-1635x3010    1923-04-15
#
#                       Job Title
# Index
# 1             Probation officer
# 2                        Dancer
# 3                          Copy
# 4      Counselling psychologist
# 5           Biomedical engineer

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 1 to 1000
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   User Id        1000 non-null   object
#  1   First Name     1000 non-null   object
#  2   Last Name      1000 non-null   object
#  3   Sex            1000 non-null   object
#  4   Email          1000 non-null   object
#  5   Phone          1000 non-null   object
#  6   Date of birth  1000 non-null   object
#  7   Job Title      1000 non-null   object
# dtypes: object(8)
# memory usage: 70.3+ KB

# %%
df.describe()
# Out:
#                 User Id First Name Last Name   Sex                Email  \
# count              1000       1000      1000  1000                 1000
# unique             1000        526       628     2                 1000
# top     8717bbf45cCDbEe      Lydia      Duke  Male  pwarner@example.org
# freq                  1          6         6   506                    1
#
#                Phone Date of birth         Job Title
# count           1000          1000              1000
# unique          1000           991               519
# top     857.139.8239    1955-07-31  Paediatric nurse
# freq               1             2                 7

# %%
del df['Email']

# %%
df.head()
# Out:
#                User Id First Name Last Name     Sex Date of birth  \
# Index
# 1      8717bbf45cCDbEe     Shelia   Mahoney    Male    2014-01-27
# 2      3d5AD30A4cD38ed         Jo    Rivers  Female    1931-07-26
# 3      810Ce0F276Badec     Sheryl    Lowery  Female    2013-11-25
# 4      BF2a889C00f0cE1    Whitney    Hooper    Male    2012-11-17
# 5      9afFEafAe1CBBB9    Lindsey      Rice  Female    1923-04-15
#
#                       Job Title
# Index
# 1             Probation officer
# 2                        Dancer
# 3                          Copy
# 4      Counselling psychologist
# 5           Biomedical engineer

# %%
col=list(df.columns)
col
# Out:
# ['User Id',
#  'First Name',
#  'Last Name',
#  'Sex',
#  'Email',
#  'Phone',
#  'Date of birth',
#  'Job Title']

# %%
l=['id','fname','lname','sex','dob','job']

# %%
mapper=dict(zip(col,l))
mapper
# Out:
# {'User Id': 'id',
#  'First Name': 'fname',
#  'Last Name': 'lname',
#  'Sex': 'sex',
#  'Email': 'dob',
#  'Phone': 'job'}

# %%
df=df.rename(mapper,axis=1)
df
# Out:
#                     id     fname     lname     sex  \
# Index
# 1      8717bbf45cCDbEe    Shelia   Mahoney    Male
# 2      3d5AD30A4cD38ed        Jo    Rivers  Female
# 3      810Ce0F276Badec    Sheryl    Lowery  Female
# 4      BF2a889C00f0cE1   Whitney    Hooper    Male
# 5      9afFEafAe1CBBB9   Lindsey      Rice  Female
# ...                ...       ...       ...     ...
# 996    fedF4c7Fd9e7cFa      Kurt    Bryant  Female
# 997    ECddaFEDdEc4FAB     Donna     Barry  Female
# 998    2adde51d8B8979E     Cathy  Mckinney  Female
# 999    Fb2FE369D1E171A  Jermaine    Phelps    Male
# 1000   8b756f6231DDC6e       Lee      Tran  Female
#
#                                  dob                    job Date of birth  \
# Index
# 1                pwarner@example.org           857.139.8239    2014-01-27
# 2      fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# 3                fhoward@example.org          (599)782-0605    2013-11-25
# ...

# %%
print(df['job'].nunique())
print(df['job'].unique())
# Out:
# 1000
# ['857.139.8239' '+1-950-759-8687' '(599)782-0605' '+1-939-130-6258'
#  '(390)417-1635x3010' '8537800927' '093.655.7480x7895' '4709522945'
#  '013.820.4758' '(560)903-5068x4985' '8629884096' '+1-041-859-3844x272'
#  '801.809.9181x37308' '+1-511-127-6660x230' '903.545.8947'
#  '(416)979-0633x058' '244-054-8521x1913' '(929)366-8549x3587'
#  '(973)243-9193' '060-611-9377x90160' '601.838.8295x89942'
#  '668.063.9568x7257' '+1-024-909-1783' '(590)187-8007x273'
#  '+1-927-383-6844' '972.064.3833x5347' '(614)275-6966x22597'
#  '(322)679-7824' '989.482.6130x996' '975-190-7875x3293'
#  '(291)853-7982x0123' '(984)863-5741x7054' '(977)846-8023'
#  '526-208-4712x10329' '5642635347' '157.425.5345' '600-706-8696x839'
#  '557-620-5663' '000-364-9407x55677' '(116)776-0713x4684'
#  '+1-932-606-8425x22206' '341.096.2708x237' '+1-833-716-3269x028'
#  '+1-262-558-4739' '001-313-023-3603x2485' '001-366-475-8607x04350'
#  '(412)388-9715' '353.983.3416' '355-371-5885x826' '+1-326-669-0118x4341'
# ...

# %%
df['job'].value_counts('Land')*1000
# Out:
# job
# 857.139.8239             1.0
# (291)707-9579x2558       1.0
# 789.800.4253x0894        1.0
# 5441639643               1.0
# 010-361-9620x13266       1.0
#                         ...
# +1-947-012-2217x8447     1.0
# (278)093-3663            1.0
# (815)610-5096x2795       1.0
# +1-460-516-0197x80941    1.0
# 079.752.5424x67259       1.0
# Name: proportion, Length: 1000, dtype: float64

# %%
df['job'].str.count('Land').sum()
# Out:
# 0

# %%
idofland=df[df['job']=='Land']['id']

# %%
id=list(idofland)[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 id=list(idofland)[0]
#
# IndexError: list index out of range

# %%
print(id)
# Out:
# <built-in function id>

# %%
df.loc[2,'sex']
# Out:
# 'Female'

# %%
df.loc[2:6]
# Out:
#                     id    fname     lname     sex  \
# Index
# 2      3d5AD30A4cD38ed       Jo    Rivers  Female
# 3      810Ce0F276Badec   Sheryl    Lowery  Female
# 4      BF2a889C00f0cE1  Whitney    Hooper    Male
# 5      9afFEafAe1CBBB9  Lindsey      Rice  Female
# 6      aF75e6dDEBC5b66   Sherry  Caldwell    Male
#
#                                  dob                 job Date of birth  \
# Index
# 2      fergusonkatherine@example.net     +1-950-759-8687    1931-07-26
# 3                fhoward@example.org       (599)782-0605    2013-11-25
# 4              zjohnston@example.com     +1-939-130-6258    2012-11-17
# 5                   elin@example.net  (390)417-1635x3010    1923-04-15
# 6              kaitlin13@example.net          8537800927    1917-08-06
#
#                        Job Title
# Index
# 2                         Dancer
# 3                           Copy
# 4       Counselling psychologist
# 5            Biomedical engineer
# 6      Higher education lecturer

# %%
df.max()
# Out:
# id                    ffD399FC7075C4b
# fname                         Zachary
# lname                          Zuniga
# sex                              Male
# dob              zsantana@example.com
# job                      995-193-0690
# Date of birth              2022-03-28
# Job Title                Youth worker
# dtype: object

# %%
df['sex'].max()
# Out:
# 'Male'

# %%
df.max()['sex']
# Out:
# 'Male'

# %%
df.describe(include=object)
# Out:
#                      id  fname lname   sex                  dob           job  \
# count              1000   1000  1000  1000                 1000          1000
# unique             1000    526   628     2                 1000          1000
# top     8717bbf45cCDbEe  Lydia  Duke  Male  pwarner@example.org  857.139.8239
# freq                  1      6     6   506                    1             1
#
#        Date of birth         Job Title
# count           1000              1000
# unique           991               519
# top       1955-07-31  Paediatric nurse
# freq               2                 7

# %%
df=pd.read_csv("superstore - Orders.csv",index_col='id')
df.head()
# Out:
#           order_id  order_date        shipment customer_id             name  \
# id
# 1   CA-2016-152156   11/8/2016    Second Class    CG-12520      Claire Gute
# 2   CA-2016-152156   11/8/2016    Second Class    CG-12520      Claire Gute
# 3   CA-2016-138688   6/12/2016    Second Class    DV-13045  Darrin Van Huff
# 4   US-2015-108966  10/11/2015  Standard Class    SO-20335   Sean O'Donnell
# 5   US-2015-108966  10/11/2015  Standard Class    SO-20335   Sean O'Donnell
#
#       segment             City       state  post_code region         category  \
# id
# 1    Consumer        Henderson    Kentucky      42420  South        Furniture
# 2    Consumer        Henderson    Kentucky      42420  South        Furniture
# 3   Corporate      Los Angeles  California      90036   West  Office Supplies
# 4    Consumer  Fort Lauderdale     Florida      33311  South        Furniture
# 5    Consumer  Fort Lauderdale     Florida      33311  South  Office Supplies
#
# ...

# %%
df['order_date']= pd.to_datetime(df['order_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9994 entries, 1 to 9994
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_id         9994 non-null   object
#  1   order_date       9994 non-null   datetime64[ns]
#  2   shipment         9994 non-null   object
#  3   customer_id      9994 non-null   object
#  4   name             9994 non-null   object
#  5   segment          9994 non-null   object
#  6   City             9994 non-null   object
#  7   state            9994 non-null   object
#  8   post_code        9994 non-null   int64
#  9   region           9994 non-null   object
#  10  category         9994 non-null   object
#  11  sub_category     9994 non-null   object
#  12  sale             9994 non-null   float64
#  13  qty              9994 non-null   int64
#  14  profit           9994 non-null   float64
#  15  returns          8816 non-null   object
# ...

# %%
df.describe()
# Out:
#                           order_date     post_code          sale          qty  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2016-04-30 00:07:12.259355648  55190.379428    229.858001     3.789574
# min              2014-01-03 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-05-23 00:00:00  23223.000000     17.280000     2.000000
# 50%              2016-06-26 00:00:00  56430.500000     54.490000     3.000000
# 75%              2017-05-14 00:00:00  90008.000000    209.940000     5.000000
# max              2017-12-30 00:00:00  99301.000000  22638.480000    14.000000
# std                              NaN  32063.693350    623.245101     2.225110
#
#             profit
# count  9994.000000
# mean     28.656896
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000
# std     234.260108

# %%
df['order_date'] = df['order_date'].dt.date

# %%
df.sort_values(by='profit',ascending=False)
# Out:
#             order_id  order_date        shipment customer_id            name  \
# id
# 6827  CA-2016-118689  2016-10-02  Standard Class    TC-20980    Tamara Chand
# 8154  CA-2017-140151  2017-03-23     First Class    RB-19360    Raymond Buch
# 4191  CA-2017-166709  2017-11-17  Standard Class    HL-15040    Hunter Lopez
# 9040  CA-2016-117121  2016-12-17  Standard Class    AB-10105   Adrian Barton
# 4099  CA-2014-116904  2014-09-23  Standard Class    SC-20095    Sanjit Chand
# ...              ...         ...             ...         ...             ...
# 4992  US-2017-122714  2017-12-07  Standard Class    HG-14965   Henry Goldwyn
# 3012  CA-2017-134845  2017-04-17  Standard Class    SR-20425  Sharelle Roach
# 9775  CA-2014-169019  2014-07-26  Standard Class    LF-17185     Luke Foster
# 684   US-2017-168116  2017-11-04        Same Day    GT-14635  Grant Thornton
# 7773  CA-2016-108196  2016-11-25  Standard Class    CS-12505   Cindy Stewart
#
# ...

# %%
import matplotlib.pyplot as mtp
df['segment'].value_counts().plot(title='segment wise order count')
# Out:
# <Axes: title={'center': 'segment wise order count'}, xlabel='segment'>

# %%
higp=df['profit'].value_counts()
higp
# Out:
# profit
# 0.0000     65
# 6.2208     43
# 9.3312     38
# 5.4432     32
# 3.6288     32
#            ..
# 83.2508     1
# 16.1096     1
# 7.1988      1
# 1.6510      1
# 72.9480     1
# Name: count, Length: 7287, dtype: int64

# %%
df.loc[(df['profit']==9.3312) & (df['segment']=='Consumer')]
# Out:
#             order_id  order_date        shipment customer_id  \
# id
# 688   CA-2014-157784  2014-07-05     First Class    MC-17845
# 1004  CA-2015-124891  2015-07-31        Same Day    RH-19495
# 1170  CA-2017-145226  2017-12-08    Second Class    DL-13315
# 1639  CA-2016-157266  2016-05-26  Standard Class    TB-21280
# 2252  CA-2015-116092  2015-02-15    Second Class    JM-16195
# 2837  CA-2017-110842  2017-11-11  Standard Class    GA-14725
# 4118  CA-2015-153416  2015-11-24  Standard Class    TS-21340
# 4312  CA-2014-125829  2014-11-04  Standard Class    WB-21850
# 4486  CA-2016-109365  2016-11-03  Standard Class    XP-21865
# 5328  CA-2014-130813  2014-01-06    Second Class    LS-17230
# 5648  CA-2017-168179  2017-11-02  Standard Class    JB-16000
# 5712  US-2015-160857  2015-05-08  Standard Class    NW-18400
# 5863  CA-2016-101525  2016-05-01    Second Class    CM-12235
# 6233  US-2017-142188  2017-09-11        Same Day    JF-15415
# ...

# %%
df['profit'].describe()
# Out:
# count    9994.000000
# mean       28.656896
# std       234.260108
# min     -6599.978000
# 25%         1.728750
# 50%         8.666500
# 75%        29.364000
# max      8399.976000
# Name: profit, dtype: float64

# %%
round(df['profit'].sum()/df['profit'].count(),1)
# Out:
# 28.7

# %%
df['profit'].mode()
# Out:
# 0    0.0
# Name: profit, dtype: float64

# %%
df.loc[df['segment']=='Consumer'].sort_values(by='profit',ascending=False).head(5)
# Out:
#             order_id  order_date        shipment customer_id  \
# id
# 8154  CA-2017-140151  2017-03-23     First Class    RB-19360
# 4191  CA-2017-166709  2017-11-17  Standard Class    HL-15040
# 9040  CA-2016-117121  2016-12-17  Standard Class    AB-10105
# 4099  CA-2014-116904  2014-09-23  Standard Class    SC-20095
# 510   CA-2015-145352  2015-03-16  Standard Class    CM-12385
#
#                       name   segment         City       state  post_code  \
# id
# 8154          Raymond Buch  Consumer      Seattle  Washington      98115
# 4191          Hunter Lopez  Consumer       Newark    Delaware      19711
# 9040         Adrian Barton  Consumer      Detroit    Michigan      48205
# 4099          Sanjit Chand  Consumer  Minneapolis   Minnesota      55407
# 510   Christopher Martinez  Consumer      Atlanta     Georgia      30318
#
#        region         category sub_category      sale  qty     profit  \
# id
# 8154     West       Technology      Copiers  13999.96    4  6719.9808
# ...

# %%
df['profit'].sample(10)
# Out:
# id
# 9036     2.7192
# 1860    25.1225
# 2844    -0.9012
# 7272     4.5448
# 9279    -5.6007
# 3899     0.8288
# 3594   -17.9424
# 3343    20.9670
# 6573     5.8604
# 5847     2.8196
# Name: profit, dtype: float64

# %%
df.loc[df['segment']=='Home Office'].sort_values('profit').head(1)
# Out:
#             order_id  order_date        shipment customer_id            name  \
# id
# 3012  CA-2017-134845  2017-04-17  Standard Class    SR-20425  Sharelle Roach
#
#           segment        City     state  post_code region    category  \
# id
# 3012  Home Office  Louisville  Colorado      80027   West  Technology
#
#      sub_category      sale  qty   profit         returns complete return
# id
# 3012     Machines  2549.985    5 -3399.98  CA-2014-116785  CA-2014-116785

# %%
df['segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['unit_price'] = df['sale']/df['qty']
df.head()
# Out:
#           order_id  order_date        shipment customer_id             name  \
# id
# 1   CA-2016-152156  2016-11-08    Second Class    CG-12520      Claire Gute
# 2   CA-2016-152156  2016-11-08    Second Class    CG-12520      Claire Gute
# 3   CA-2016-138688  2016-06-12    Second Class    DV-13045  Darrin Van Huff
# 4   US-2015-108966  2015-10-11  Standard Class    SO-20335   Sean O'Donnell
# 5   US-2015-108966  2015-10-11  Standard Class    SO-20335   Sean O'Donnell
#
#       segment             City       state  post_code region         category  \
# id
# 1    Consumer        Henderson    Kentucky      42420  South        Furniture
# 2    Consumer        Henderson    Kentucky      42420  South        Furniture
# 3   Corporate      Los Angeles  California      90036   West  Office Supplies
# 4    Consumer  Fort Lauderdale     Florida      33311  South        Furniture
# 5    Consumer  Fort Lauderdale     Florida      33311  South  Office Supplies
#
# ...

# %%
df['pp'] = df['profit']/df['sale']*100

# %%
df.head()
# Out:
#           order_id  order_date        shipment customer_id             name  \
# id
# 1   CA-2016-152156  2016-11-08    Second Class    CG-12520      Claire Gute
# 2   CA-2016-152156  2016-11-08    Second Class    CG-12520      Claire Gute
# 3   CA-2016-138688  2016-06-12    Second Class    DV-13045  Darrin Van Huff
# 4   US-2015-108966  2015-10-11  Standard Class    SO-20335   Sean O'Donnell
# 5   US-2015-108966  2015-10-11  Standard Class    SO-20335   Sean O'Donnell
#
#       segment             City       state  post_code region         category  \
# id
# 1    Consumer        Henderson    Kentucky      42420  South        Furniture
# 2    Consumer        Henderson    Kentucky      42420  South        Furniture
# 3   Corporate      Los Angeles  California      90036   West  Office Supplies
# 4    Consumer  Fort Lauderdale     Florida      33311  South        Furniture
# 5    Consumer  Fort Lauderdale     Florida      33311  South  Office Supplies
#
# ...

# %%
df.groupby('segment')

# %%
df.loc[df['profit']==df['profit'].max(),'order_id']
# Out:
# id
# 6827    CA-2016-118689
# Name: order_id, dtype: object

# %%
df.loc[df['pp']==df['pp'].max()].sort_values('name').head(1)
# Out:
#             order_id  order_date  shipment customer_id       name    segment  \
# id
# 8688  CA-2016-144015  2016-06-26  Same Day    AH-10075  Adam Hart  Corporate
#
#              City       state  post_code region         category sub_category  \
# id
# 8688  Los Angeles  California      90036   West  Office Supplies    Fasteners
#
#       sale  qty  profit         returns complete return  unit_price    pp
# id
# 8688  17.9    5    8.95  CA-2014-164721  CA-2014-164721        3.58  50.0

# %%
df.rename({'order_id':'orderid'},axis=1,inplace=True)

# %%
df.head(1)
# Out:
#            orderid  order_date      shipment customer_id         name  \
# id
# 1   CA-2016-152156  2016-11-08  Second Class    CG-12520  Claire Gute
#
#      segment       City     state  post_code region   category sub_category  \
# id
# 1   Consumer  Henderson  Kentucky      42420  South  Furniture    Bookcases
#
#       sale  qty   profit         returns complete return  unit_price    pp
# id
# 1   261.96    2  41.9136  CA-2014-166744  CA-2014-166744      130.98  16.0

# %%
df.query('segment == "Consumer"')
# Out:
#              orderid  order_date        shipment customer_id  \
# id
# 1     CA-2016-152156  2016-11-08    Second Class    CG-12520
# 2     CA-2016-152156  2016-11-08    Second Class    CG-12520
# 4     US-2015-108966  2015-10-11  Standard Class    SO-20335
# 5     US-2015-108966  2015-10-11  Standard Class    SO-20335
# 6     CA-2014-115812  2014-06-09  Standard Class    BH-11710
# ...              ...         ...             ...         ...
# 9990  CA-2014-110422  2014-01-21    Second Class    TB-21400
# 9991  CA-2017-121258  2017-02-26  Standard Class    DB-13060
# 9992  CA-2017-121258  2017-02-26  Standard Class    DB-13060
# 9993  CA-2017-121258  2017-02-26  Standard Class    DB-13060
# 9994  CA-2017-119914  2017-05-04    Second Class    CC-12220
#
#                   name   segment             City       state  post_code  \
# id
# 1          Claire Gute  Consumer        Henderson    Kentucky      42420
# 2          Claire Gute  Consumer        Henderson    Kentucky      42420
# ...

# %%
df['profit'].max()
# Out:
# 8399.976

# %%
m=df['profit'].mean()
m
df.query('profit > @m and segment == "Consumer"')
# Out:
#              orderid  order_date        shipment customer_id             name  \
# id
# 1     CA-2016-152156  2016-11-08    Second Class    CG-12520      Claire Gute
# 2     CA-2016-152156  2016-11-08    Second Class    CG-12520      Claire Gute
# 8     CA-2014-115812  2014-06-09  Standard Class    BH-11710  Brosina Hoffman
# 10    CA-2014-115812  2014-06-09  Standard Class    BH-11710  Brosina Hoffman
# 11    CA-2014-115812  2014-06-09  Standard Class    BH-11710  Brosina Hoffman
# ...              ...         ...             ...         ...              ...
# 9942  CA-2017-164028  2017-11-24  Standard Class    JL-15835         John Lee
# 9943  CA-2014-143371  2014-12-28  Standard Class    MD-17350    Maribeth Dona
# 9969  CA-2017-153871  2017-12-11  Standard Class    RB-19435  Richard Bierner
# 9973  CA-2016-130225  2016-09-11  Standard Class    RC-19960       Ryan Crowe
# 9994  CA-2017-119914  2017-05-04    Second Class    CC-12220     Chris Cortes
#
# ...

# %%
df.query('segment == "Consumer"')
# Out:
#              orderid  order_date        shipment customer_id  \
# id
# 1     CA-2016-152156  2016-11-08    Second Class    CG-12520
# 2     CA-2016-152156  2016-11-08    Second Class    CG-12520
# 4     US-2015-108966  2015-10-11  Standard Class    SO-20335
# 5     US-2015-108966  2015-10-11  Standard Class    SO-20335
# 6     CA-2014-115812  2014-06-09  Standard Class    BH-11710
# ...              ...         ...             ...         ...
# 9990  CA-2014-110422  2014-01-21    Second Class    TB-21400
# 9991  CA-2017-121258  2017-02-26  Standard Class    DB-13060
# 9992  CA-2017-121258  2017-02-26  Standard Class    DB-13060
# 9993  CA-2017-121258  2017-02-26  Standard Class    DB-13060
# 9994  CA-2017-119914  2017-05-04    Second Class    CC-12220
#
#                   name   segment             City       state  post_code  \
# id
# 1          Claire Gute  Consumer        Henderson    Kentucky      42420
# 2          Claire Gute  Consumer        Henderson    Kentucky      42420
# ...

# %%
df.loc[(df['segment']=='Consumer') & (df['profit']>500),'orderid'].shape
# Out:
# (55,)

# %%
def abc(a):
    if a>0:
        return 'positive'
    elif a==0:
        return 'zero'
    else:
        return 'negative'

# %%
df1= df[['profit','segment']]

# %%
df1.groupby('segment')['profit'].mean()
# Out:
# segment
# Consumer       25.836873
# Corporate      30.456667
# Home Office    33.818664
# Name: profit, dtype: float64

# %%
pd.DataFrame(df.groupby('segment')['segment'].count().sort_values(ascending=False))
# Out:
#              segment
# segment
# Consumer        5191
# Corporate       3020
# Home Office     1783

# %%
df.head(1)
# Out:
#            orderid  order_date      shipment customer_id         name  \
# id
# 1   CA-2016-152156  2016-11-08  Second Class    CG-12520  Claire Gute
#
#      segment       City     state  post_code region   category sub_category  \
# id
# 1   Consumer  Henderson  Kentucky      42420  South  Furniture    Bookcases
#
#       sale  qty   profit         returns complete return  unit_price    pp
# id
# 1   261.96    2  41.9136  CA-2014-166744  CA-2014-166744      130.98  16.0

# %%
import matplotlib as mtp

# %%
df['segment'].value_counts().plot(kind='bar',title='Order count by segment',xlabel='Segments',ylabel='Order count')
# Out:
# <Axes: title={'center': 'Order count by segment'}, xlabel='Segments', ylabel='Order count'>

# %%
df.head(1)
# Out:
#            orderid  order_date      shipment customer_id         name  \
# id
# 1   CA-2016-152156  2016-11-08  Second Class    CG-12520  Claire Gute
#
#      segment       City     state  post_code region   category sub_category  \
# id
# 1   Consumer  Henderson  Kentucky      42420  South  Furniture    Bookcases
#
#       sale  qty   profit         returns complete return  unit_price    pp
# id
# 1   261.96    2  41.9136  CA-2014-166744  CA-2014-166744      130.98  16.0

# %%
df['segment'].value_counts()
# Out:
# segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
df.loc[~df['segment'].isin(['Consumer','Corporate'])].head()
# Out:
#            orderid  order_date        shipment customer_id           name  \
# id
# 15  US-2015-118983  2015-11-22  Standard Class    HP-14815  Harold Pawlan
# 16  US-2015-118983  2015-11-22  Standard Class    HP-14815  Harold Pawlan
# 35  CA-2017-107727  2017-10-19    Second Class    MA-17560   Matt Abelman
# 38  CA-2015-117415  2015-12-27  Standard Class    SN-20710   Steve Nguyen
# 39  CA-2015-117415  2015-12-27  Standard Class    SN-20710   Steve Nguyen
#
#         segment        City  state  post_code   region         category  \
# id
# 15  Home Office  Fort Worth  Texas      76106  Central  Office Supplies
# 16  Home Office  Fort Worth  Texas      76106  Central  Office Supplies
# 35  Home Office     Houston  Texas      77095  Central  Office Supplies
# 38  Home Office     Houston  Texas      77041  Central  Office Supplies
# 39  Home Office     Houston  Texas      77041  Central        Furniture
#
#    sub_category      sale  qty    profit         returns complete return  \
# ...

# %%
df.query('segment == "Consumer"').groupby('City')['profit'].sum().sort_values(ascending=False).head(10).plot(kind='bar',color='red')
# Out:
# <Axes: xlabel='City'>

# %%
low5 = df['profit'].quantile(.01)
hig5  = df['profit'].quantile(0.99)
(low5,hig5)
# Out:
# (-319.264953, 580.6578819999995)

# %%
df.loc[(df['profit']<low5) | (df['profit']>hig5) ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.loc[(df['profit']<low5) | (df['profit']>hig5) ]
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
#                User Id First Name Last Name     Sex  \
# Index
# 1      8717bbf45cCDbEe     Shelia   Mahoney    Male
# 2      3d5AD30A4cD38ed         Jo    Rivers  Female
# 3      810Ce0F276Badec     Sheryl    Lowery  Female
# 4      BF2a889C00f0cE1    Whitney    Hooper    Male
# 5      9afFEafAe1CBBB9    Lindsey      Rice  Female
#
#                                Email               Phone Date of birth  \
# Index
# 1                pwarner@example.org        857.139.8239    2014-01-27
# 2      fergusonkatherine@example.net     +1-950-759-8687    1931-07-26
# 3                fhoward@example.org       (599)782-0605    2013-11-25
# 4              zjohnston@example.com     +1-939-130-6258    2012-11-17
# 5                   elin@example.net  (390)417-1635x3010    1923-04-15
#
#                       Job Title
# Index
# 1             Probation officer
# 2                        Dancer
# 3                          Copy
# 4      Counselling psychologist
# 5           Biomedical engineer

# %%
df.head(1)
# Out:
#           order_id  order_date      shipment customer_id         name  \
# id
# 1   CA-2016-152156  2016-11-08  Second Class    CG-12520  Claire Gute
#
#      segment       City     state  post_code region   category sub_category  \
# id
# 1   Consumer  Henderson  Kentucky      42420  South  Furniture    Bookcases
#
#       sale  qty   profit         returns complete return
# id
# 1   261.96    2  41.9136  CA-2014-166744  CA-2014-166744

# %%
df.dtypes('order_date')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.dtypes('order_date')
#
# TypeError: 'Series' object is not callable

# %%
df['date'] = pd.to_datetime(df['order_date'])

# %%
df.head()
# Out:
#           order_id  order_date        shipment customer_id             name  \
# id
# 1   CA-2016-152156  2016-11-08    Second Class    CG-12520      Claire Gute
# 2   CA-2016-152156  2016-11-08    Second Class    CG-12520      Claire Gute
# 3   CA-2016-138688  2016-06-12    Second Class    DV-13045  Darrin Van Huff
# 4   US-2015-108966  2015-10-11  Standard Class    SO-20335   Sean O'Donnell
# 5   US-2015-108966  2015-10-11  Standard Class    SO-20335   Sean O'Donnell
#
#       segment             City       state  post_code region         category  \
# id
# 1    Consumer        Henderson    Kentucky      42420  South        Furniture
# 2    Consumer        Henderson    Kentucky      42420  South        Furniture
# 3   Corporate      Los Angeles  California      90036   West  Office Supplies
# 4    Consumer  Fort Lauderdale     Florida      33311  South        Furniture
# 5    Consumer  Fort Lauderdale     Florida      33311  South  Office Supplies
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9994 entries, 1 to 9994
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_id         9994 non-null   object
#  1   order_date       9994 non-null   object
#  2   shipment         9994 non-null   object
#  3   customer_id      9994 non-null   object
#  4   name             9994 non-null   object
#  5   segment          9994 non-null   object
#  6   City             9994 non-null   object
#  7   state            9994 non-null   object
#  8   post_code        9994 non-null   int64
#  9   region           9994 non-null   object
#  10  category         9994 non-null   object
#  11  sub_category     9994 non-null   object
#  12  sale             9994 non-null   float64
#  13  qty              9994 non-null   int64
#  14  profit           9994 non-null   float64
#  15  returns          8816 non-null   object
#  16  complete return  9994 non-null   object
# ...

# %%
import datetime as dt
df['new date'] = df['date'].dt.strftime('%m-%d')

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9994 entries, 1 to 9994
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_id         9994 non-null   object
#  1   order_date       9994 non-null   object
#  2   shipment         9994 non-null   object
#  3   customer_id      9994 non-null   object
#  4   name             9994 non-null   object
#  5   segment          9994 non-null   object
#  6   City             9994 non-null   object
#  7   state            9994 non-null   object
#  8   post_code        9994 non-null   int64
#  9   region           9994 non-null   object
#  10  category         9994 non-null   object
#  11  sub_category     9994 non-null   object
#  12  sale             9994 non-null   float64
#  13  qty              9994 non-null   int64
#  14  profit           9994 non-null   float64
#  15  returns          8816 non-null   object
#  16  complete return  9994 non-null   object
# ...

# %%
df.head()
# Out:
#           order_id  order_date        shipment customer_id             name  \
# id
# 1   CA-2016-152156  2016-11-08    Second Class    CG-12520      Claire Gute
# 2   CA-2016-152156  2016-11-08    Second Class    CG-12520      Claire Gute
# 3   CA-2016-138688  2016-06-12    Second Class    DV-13045  Darrin Van Huff
# 4   US-2015-108966  2015-10-11  Standard Class    SO-20335   Sean O'Donnell
# 5   US-2015-108966  2015-10-11  Standard Class    SO-20335   Sean O'Donnell
#
#       segment             City       state  post_code region         category  \
# id
# 1    Consumer        Henderson    Kentucky      42420  South        Furniture
# 2    Consumer        Henderson    Kentucky      42420  South        Furniture
# 3   Corporate      Los Angeles  California      90036   West  Office Supplies
# 4    Consumer  Fort Lauderdale     Florida      33311  South        Furniture
# 5    Consumer  Fort Lauderdale     Florida      33311  South  Office Supplies
#
# ...

# %%
df.head()
# Out:
#           order_id  order_date        shipment customer_id             name  \
# id
# 1   CA-2016-152156  2016-11-08    Second Class    CG-12520      Claire Gute
# 2   CA-2016-152156  2016-11-08    Second Class    CG-12520      Claire Gute
# 3   CA-2016-138688  2016-06-12    Second Class    DV-13045  Darrin Van Huff
# 4   US-2015-108966  2015-10-11  Standard Class    SO-20335   Sean O'Donnell
# 5   US-2015-108966  2015-10-11  Standard Class    SO-20335   Sean O'Donnell
#
#       segment             City       state  post_code region         category  \
# id
# 1    Consumer        Henderson    Kentucky      42420  South        Furniture
# 2    Consumer        Henderson    Kentucky      42420  South        Furniture
# 3   Corporate      Los Angeles  California      90036   West  Office Supplies
# 4    Consumer  Fort Lauderdale     Florida      33311  South        Furniture
# 5    Consumer  Fort Lauderdale     Florida      33311  South  Office Supplies
#
# ...

# %% [markdown]
# #### itertool product will make combination of two iterable elements

# %%
l=[1,2,3,4,5]
l1=list('abcd')
import itertools as it
a=it.product(l,l1)
print(list(a))
# Out:
# [(1, 'a'), (1, 'b'), (1, 'c'), (1, 'd'), (2, 'a'), (2, 'b'), (2, 'c'), (2, 'd'), (3, 'a'), (3, 'b'), (3, 'c'), (3, 'd'), (4, 'a'), (4, 'b'), (4, 'c'), (4, 'd'), (5, 'a'), (5, 'b'), (5, 'c'), (5, 'd')]
