# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import devesh as d

# %%
df = pd.read_excel('transport_data.xlsx')

# %%
df.shape
# Out:
# (1808, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1808 entries, 970 to 374
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tripid            1808 non-null   int64
#  1   shipperid         1808 non-null   int64
#  2   categoryid        1808 non-null   int64
#  3   customer          1808 non-null   object
#  4   shipdate          1808 non-null   object
#  5   origincity        1808 non-null   object
#  6   originstate       1808 non-null   object
#  7   shipdays          1808 non-null   int64
#  8   destinationcity   1808 non-null   object
#  9   destinationstate  1808 non-null   object
#  10  deliverydate      1808 non-null   datetime64[ns]
#  11  totalmiles        1808 non-null   int64
#  12  loadedmiles       1808 non-null   int64
#  13  shippingcost      1808 non-null   int64
#  14  revenue           1808 non-null   int64
#  15  capacity          1808 non-null   int64
# ...

# %%
df.describe()
# Out:
#              tripid    shipperid   categoryid     shipdays  \
# count   1808.000000  1808.000000  1808.000000  1808.000000
# mean   10904.500000     1.982854     4.678650     4.238385
# min    10001.000000     1.000000     1.000000     1.000000
# 25%    10452.750000     1.000000     3.000000     2.000000
# 50%    10904.500000     2.000000     5.000000     3.000000
# 75%    11356.250000     2.000000     6.000000     6.000000
# max    11808.000000     3.000000     8.000000    10.000000
# std      522.068961     0.716038     2.048971     2.832167
#
#                         deliverydate   totalmiles  loadedmiles  shippingcost  \
# count                           1808  1808.000000  1808.000000   1808.000000
# mean   2016-05-05 07:56:16.991150336   699.450221   439.000000   4356.649889
# min              2016-01-02 00:00:00   200.000000   200.000000      8.000000
# 25%              2016-03-11 00:00:00   445.750000   297.000000   2272.250000
# ...

# %%
df.columns
# Out:
# Index(['TripID', 'ShipperID', 'CategoryID', 'Customer', 'ShipDate',
#        'OriginCity', 'OriginState', 'ShipDays', 'DestinationCity',
#        'DestinationState', 'DeliveryDate', 'TotalMiles', 'LoadedMiles',
#        'ShippingCost', 'Revenue', 'Capacity', 'TripType', 'CheckPoints'],
#       dtype='object')

# %%
d.histall(df)

# %%
df.describe()
# Out:
#              TripID    ShipperID   CategoryID     ShipDays   TotalMiles  \
# count   1808.000000  1808.000000  1808.000000  1808.000000  1808.000000
# mean   10904.500000     1.982854     4.678650     4.238385   699.450221
# std      522.068961     0.716038     2.048971     2.832167   290.378782
# min    10001.000000     1.000000     1.000000     1.000000   200.000000
# 25%    10452.750000     1.000000     3.000000     2.000000   445.750000
# 50%    10904.500000     2.000000     5.000000     3.000000   704.000000
# 75%    11356.250000     2.000000     6.000000     6.000000   955.250000
# max    11808.000000     3.000000     8.000000    10.000000  1200.000000
#
#        LoadedMiles  ShippingCost       Revenue     Capacity  CheckPoints
# count  1808.000000   1808.000000   1808.000000  1808.000000  1808.000000
# mean    439.000000   4356.649889   4874.645465    74.643805     5.445243
# std     164.265857   2470.158758   2693.405007    14.793966     2.854581
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1808 entries, 970 to 374
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tripid            1808 non-null   int64
#  1   shipperid         1808 non-null   int64
#  2   categoryid        1808 non-null   int64
#  3   customer          1808 non-null   object
#  4   shipdate          1808 non-null   object
#  5   origincity        1808 non-null   object
#  6   originstate       1808 non-null   object
#  7   shipdays          1808 non-null   int64
#  8   destinationcity   1808 non-null   object
#  9   destinationstate  1808 non-null   object
#  10  deliverydate      1808 non-null   datetime64[ns]
#  11  totalmiles        1808 non-null   int64
#  12  loadedmiles       1808 non-null   int64
#  13  shippingcost      1808 non-null   int64
#  14  revenue           1808 non-null   int64
#  15  capacity          1808 non-null   int64
# ...

# %%
df =d.fix_col(df)

# %%
df['newshipdate'] = pd.to_datetime(df['shipdate'],format="%d-%m-%Y")

# %%
df['newdeliverydate']
# Out:
# 0      2016-07-09
# 1      2016-05-23
# 2      2016-08-29
# 3      2016-05-21
# 4      2016-04-28
#           ...
# 1803   2016-03-21
# 1804   2016-07-08
# 1805   2016-03-13
# 1806   2016-08-05
# 1807   2016-02-19
# Name: newdeliverydate, Length: 1808, dtype: datetime64[ns]

# %%
df['newdeliverydate'] = pd.to_datetime(df['deliverydate'],format="%d-%m-%Y")

# %%
df['month'] = df['newshipdate'].dt.month

# %%
df['day'] = df['newshipdate'].dt.day

# %%
df.head(2).T
# Out:
#                                   970                  952
# tripid                          10971                10953
# shipperid                           2                    3
# categoryid                          3                    3
# customer                    Condintex               Plusla
# shipdate                   01-01-2016           01-01-2016
# origincity                Springfield              Chicago
# originstate                        IL                   IL
# shipdays                            2                    5
# destinationcity                Skokie             Rockford
# destinationstate                   IL                   IL
# deliverydate      2016-01-03 00:00:00  2016-01-05 00:00:00
# totalmiles                        710                  780
# loadedmiles                       710                  275
# shippingcost                     1122                 5832
# revenue                          1831                 6808
# ...

# %%
sns.histplot(data=df,x='day')
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
df =df.sort_values(by='newshipdate')

# %%
df['profit'] = df['revenue']-df['shippingcost']

# %%
df['datediff'] = df['newdeliverydate']-df['newshipdate']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1808 entries, 970 to 374
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tripid            1808 non-null   int64
#  1   shipperid         1808 non-null   int64
#  2   categoryid        1808 non-null   int64
#  3   customer          1808 non-null   object
#  4   shipdate          1808 non-null   object
#  5   origincity        1808 non-null   object
#  6   originstate       1808 non-null   object
#  7   shipdays          1808 non-null   int64
#  8   destinationcity   1808 non-null   object
#  9   destinationstate  1808 non-null   object
#  10  deliverydate      1808 non-null   datetime64[ns]
#  11  totalmiles        1808 non-null   int64
#  12  loadedmiles       1808 non-null   int64
#  13  shippingcost      1808 non-null   int64
#  14  revenue           1808 non-null   int64
#  15  capacity          1808 non-null   int64
# ...

# %%
df.loc[df['datediff']=='-161 days']
# Out:
#     tripid  shipperid  categoryid customer    shipdate origincity originstate  \
# 76   10077          1           5  Pluslam  29-08-2016     Skokie          IL
#
#     shipdays destinationcity destinationstate  ... revenue  capacity  \
# 76         9         Chicago               IL  ...    2742        87
#
#          triptype  checkpoints  newshipdate  newdeliverydate month  day  \
# 76  International            8   2016-08-29       2016-03-21     8   29
#
#    profit  datediff
# 76    788 -161 days
#
# [1 rows x 24 columns]

# %%
df['datediff'].unique()
# Out:
# <TimedeltaArray>
# [   '1 days',    '2 days',    '4 days',    '3 days',   '10 days',    '5 days',
#     '6 days',    '7 days', '-124 days',    '9 days',    '8 days',   '60 days',
#    '53 days', '-161 days', '-157 days',  '-91 days',    '0 days', '-145 days',
#  '-132 days',  '-56 days',  '-79 days',   '58 days',   '29 days',   '79 days',
#   '-43 days', '-112 days',   '68 days', '-158 days', '-133 days',  '-33 days',
#    '56 days', '-148 days', '-141 days',  '-37 days',  '-26 days',   '-6 days',
#   '-16 days', '-113 days',   '42 days',   '52 days',   '40 days', '-137 days',
#   '-86 days', '-117 days',   '11 days',   '15 days',  '-84 days',   '17 days',
#  '-127 days',  '-48 days',  '-96 days',   '26 days',   '77 days',  '-31 days',
#    '13 days', '-109 days',   '55 days',  '-12 days',   '59 days',  '-35 days',
#   '-21 days',   '36 days',  '-23 days',   '78 days', '-106 days', '-138 days',
#    '25 days',   '73 days',  '-32 days',  '-85 days', '-128 days',   '34 days',
# ...

# %%
df.to_csv('transport_data_clean.csv')

# %%
df['revenue running totel'] = df['revenue'].cumsum()

# %%
df['cost running totel'] = df['shippingcost'].cumsum()

# %%
df.sample(2).T
# Out:
#                                       1401                 1734
# tripid                               11402                11735
# shipperid                                3                    2
# categoryid                               5                    4
# customer                           Scotlex             Dongbase
# shipdate                        22-02-2016           03-07-2016
# origincity                        Appleton            Milwaukee
# originstate                             WI                   WI
# shipdays                                 6                    1
# destinationcity               Grand Rapids          Springfield
# destinationstate                        MI                   IL
# deliverydate                    28-02-2016           04-07-2016
# totalmiles                             253                  598
# loadedmiles                            253                  598
# shippingcost                          2142                 2915
# ...

# %%
sns.lineplot(y='cost running totel',x='newshipdate',data=df)
# Out:
# <Axes: xlabel='newshipdate', ylabel='cost running totel'>
