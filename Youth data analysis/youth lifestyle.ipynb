# %%
import pandas as pd

# %%
df = pd.read_csv('youth_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243071 entries, 0 to 243070
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ID                      243071 non-null  int64
#  1   YEAR                    243071 non-null  int64
#  2   YEAR_OF_BIRTH           243071 non-null  int64
#  3   COUNTRY_OF_BIRTH        243071 non-null  object
#  4   SAMPLE_RACE             243071 non-null  object
#  5   SAMPLE_SEX              243071 non-null  object
#  6   C1DOB_Y                 243071 non-null  object
#  7   HAVING_HEALTHPLAN       107711 non-null  object
#  8   FAMSIZE_                243071 non-null  int64
#  9   TNFI_                   243071 non-null  int64
#  10  POVSTATUS_              243071 non-null  object
#  11  REGION_                 243071 non-null  object
#  12  MARSTAT_KEY_            243071 non-null  object
#  13  WKSUEMP_PCY_            243071 non-null  int64
# ...

# %%
df.head(2).T
# Out:
#                                               0                        1
# ID                                            1                        1
# YEAR                                       1979                     1981
# YEAR_OF_BIRTH                                58                       58
# COUNTRY_OF_BIRTH                      IN THE US                IN THE US
# SAMPLE_RACE             NON-BLACK, NON-HISPANIC  NON-BLACK, NON-HISPANIC
# SAMPLE_SEX                               FEMALE                   FEMALE
# C1DOB_Y                         No children yet          No children yet
# HAVING_HEALTHPLAN                           NaN                      NaN
# FAMSIZE_                                      5                        5
# TNFI_                                     30000                       -3
# POVSTATUS_                    0: NOT IN POVERTY                       -3
# REGION_                            1: NORTHEAST             1: NORTHEAST
# ...

# %%
df.shape
# Out:
# (243071, 36)

# %%
df.nunique()
# Out:
# ID                        12685
# YEAR                         25
# YEAR_OF_BIRTH                 8
# COUNTRY_OF_BIRTH              3
# SAMPLE_RACE                   3
# SAMPLE_SEX                    2
# C1DOB_Y                      48
# HAVING_HEALTHPLAN             7
# FAMSIZE_                     19
# TNFI_                     30603
# POVSTATUS_                    4
# REGION_                       6
# MARSTAT_KEY_                 10
# WKSUEMP_PCY_                 56
# URBAN_RURAL_                  6
# JOBSNUM_                     59
# NUMCH_                       12
# AGE_1STCHILD                 42
# EVER_IN_POVERTY               2
# WHEN_IN_POVERTY               4
# INCOME_                   11591
# INCOME_MAX                 1429
# EVER_EDU_LOAN                 3
# EDU_DEGREE                    9
# EVER_DIVORCED_                3
# EVER_UNEMPLOYED_              2
# HOURS_WORKED_PER_WEEK_      188
# MAJOR_1_                    445
# MAJOR_2_                    234
# ...
