# %%
try:
    print(a)
except:
    print("There was an error")
# Out:
# There was an error

# %%
a = 56

# %%
del a

# %%
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(b)
#
# NameError: name 'b' is not defined

# %%
d=  {1:100,2:200}
try:
    e[3]
except KeyError:
    print("there is no key")
except:
    print("something is wrong")
# Out:
# something is wrong

# %%
a=  "33.6"
try:
    a = int(a)
except ValueError:
    try:
        a = float(a)
    except:
        print("a is not a float or a int so its str")
        a = str(a)
    
        

print(a,type(a))
# Out:
# 33.6 <class 'float'>

# %%
try:
  print("Hello")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %%
x = -1

if x < 0:
  raise Exception("Sorry, no numbers below zero")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 x = -1
#       3 if x < 0:
# ----> 4   raise Exception("Sorry, no numbers below zero")
#
# Exception: Sorry, no numbers below zero

# %%
x = "hello"

if not type(x) is int:
  raise TypeError("Only integers are allowed")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 x = "hello"
#       3 if not type(x) is int:
# ----> 4   raise TypeError("Only integers are allowed")
#
# TypeError: Only integers are allowed

# %%
a = 999
b= f"hello the value is {a}"
b
# Out:
# 'hello the value is 999'

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %%
print(f"hello val is {45:5f}")
# Out:
# hello val is 45.000000

# %%
a = 23455676
print(f"value is {a:,}")
print(f"value is {a:.2f}")
print(f"value is {a:,.4f}")
# Out:
# value is 23,455,676
# value is 23455676.00
# value is 23,455,676.0000

# %%
price = 499
txt = f"It is very {'Expensive' if price>50 else 'Cheap'}"

print(txt)
# Out:
# It is very Expensive

# %%
a = 67
print(f"{a:b}")
# Out:
# 1000011

# %%
a = 32900
len(f"{a:b}")
# Out:
# 16

# %%
import numpy as np
a = np.int8(4)
a.itemsize
# Out:
# 1

# %%
a= 0.12
f"{a:%}"
# Out:
# '12.000000%'
